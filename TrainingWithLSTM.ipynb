# %% [markdown]
# # Import Dependencies

# %%
import numpy as np
import os
from keras.layers.convolutional import Conv3D, MaxPooling3D
from keras.layers.core import Dense, Dropout, Flatten
from keras.models import Sequential
from keras.layers import Activation, ZeroPadding3D, TimeDistributed, LSTM, GRU, Reshape, BatchNormalization, Bidirectional
from keras.utils import plot_model
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
from sklearn.model_selection import train_test_split
import gc
from sklearn.metrics import classification_report, balanced_accuracy_score
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle
from sklearn.preprocessing import LabelEncoder
import sklearn
import seaborn as sns
import tensorflow as tf
from keras import regularizers
from prettytable import PrettyTable
from tqdm import tqdm

# %%
for root, dirs, files in os.walk('D:/Programming/Code/Python/CustomLipReading/data'):
    print(root)

# %%
# Set the directory path where the text files are located
dir_path = "D:/Programming/Code/Python/CustomLipReading/data"

# Set the dimensions of each frame
height, width, channels = 80, 112, 3

# Initialize arrays to store the video frames and their corresponding labels
videos = []
labels = []
counter = 0
i = 0
# Loop through each text file and extract the video frames
for root, dirs, files in tqdm(os.walk(dir_path), total=604):
    # print(root, end='\r')
    for file in files:
        # print(file)
        if file == "data.txt":

            # Extract the label from the directory name
            label = root.split("/")[-1]
            label = label.split("_")[0]
            #if label not in wanted_words:
            #    continue
            counter += 1
            # print(counter, end=" ")
            

            with open(os.path.join(root, file), 'r') as f:
                data_str = f.read()

            # Evaluate the contents of the text file as a Python expression
            data_list = eval(data_str)
            
            # Convert the list to a numpy array
            data_array = np.array(data_list)
            #print(data_array.shape)

            # Reshape the data into a 4D array of shape (num_frames, height, width, channels)
            num_frames = len(data_list)
            frames = data_array.reshape((num_frames, height, width, channels))
            # Append the frames and label to the videos and labels arrays
            videos.append(frames)
            labels.append(label)
# print(labels)

# Convert the videos and labels arrays to NumPy arrays
videos = np.array(videos)
labels = np.array(labels)

# Save the videos and labels as separate .npy files
np.save("vid/videosCorrect.npy", videos)
np.save("vid/labelsCorrect.npy", labels)
# Out:
# 100%|██████████| 604/604 [16:39<00:00,  1.65s/it]

# %%
video_path = 'vid/videosCorrect.npy'
label_path = 'vid/labelsCorrect.npy'

videos = np.load(video_path)
labels = np.load(label_path)

# %%
# Print the shape of the videos and labels arrays
print("Videos shape:", videos.shape)
print("Labels shape:", labels.shape)
# Out:
# Videos shape: (2080, 22, 80, 112, 3)
# Labels shape: (2080,)

# %%
encoder = LabelEncoder()
encoder.fit(labels)
encoded_labels = encoder.transform(labels)
labels = encoded_labels

# %% [markdown]
# # Label preprocessing

# %%
fprop = fm.FontProperties(fname='Language/AnnapurnaSIL-Regular.ttf')

# %%
label_dict = {0: 'अच्छा', 1: 'एक', 2: 'और', 3: 'कहाँ', 4: 'चार', 5: 'जी', 6: 'ठीक', 7: 'तीन', 8: 'दस', 9: 'देखो', 10: 'नमस्ते', 11: 'पाँच', 12: 'पानी', 13: 'रोटी', 14: 'है'}

# %%
# Get the unique classes
classes = np.unique(labels)

# Count the number of occurrences of each class
counts = np.bincount(labels, minlength=len(classes))

# Find the maximum length of the class names for alignment
max_len = max([len(label_dict[i]) for i in range(len(label_dict))])

# Print the distribution of classes
for i, count in enumerate(counts):
    class_name = label_dict[i].ljust(max_len)
    print("{}  {} counts".format(class_name, count))
# Out:
# अच्छा   156 counts
# एक      168 counts
# और      120 counts
# कहाँ    150 counts
# चार     128 counts
# जी      120 counts
# ठीक     168 counts
# तीन     150 counts
# दस      120 counts
# देखो    128 counts
# नमस्ते  120 counts
# पाँच    150 counts
# पानी    132 counts
# रोटी    150 counts
# है      120 counts

# %%
# Get the unique classes
classes = np.unique(labels)

# Count the number of occurrences of each class
counts = np.bincount(labels, minlength=len(classes))

# Set the figure size and font size
plt.figure(figsize=(8, 6))
plt.rcParams.update({'font.size': 12})

# Plot the histogram
plt.hist(labels, bins=len(classes), width=0.8)
plt.xticks(range(len(classes)), [label_dict[i] for i in range(len(classes))], rotation=45, ha='right', fontproperties=fprop)
plt.xlabel('Classes')
plt.ylabel('Counts')
plt.title('Distribution of Classes')

# Display the plot
plt.show()

# %% [markdown]
# # Creating the test-train split

# %%
# Split the data into training and validation sets

X_train, X_test, y_train, y_test = train_test_split(videos, labels, test_size=0.2, random_state=42)

print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)

del videos
# Out:
# Training set shape: (1664, 22, 80, 112, 3) (1664,)
# Test set shape: (416, 22, 80, 112, 3) (416,)

# %% [markdown]
# # Model Creation

# %%
# With temporal modeling

# Define video input shape
input_shape = (22, 80, 112, 3)

# Model definition
model = Sequential()
model.add(Conv3D(8, (3, 3, 3), activation='relu', input_shape=input_shape, kernel_regularizer=regularizers.l2(0.5)))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.75))

model.add(Conv3D(8, (3, 3, 3), activation='relu', kernel_regularizer=regularizers.l2(0.5)))
model.add(BatchNormalization())
model.add(MaxPooling3D((2, 2, 2)))
model.add(Dropout(0.75))

model.add(Reshape((18, -1)))

# Bi-directional LSTM for temporal attention
model.add(Bidirectional(LSTM(64, return_sequences=True)))

# Add another LSTM layer (optional)
# model.add(LSTM(32))

# Flatten the output
model.add(Flatten())

# Dense layers for classification
model.add(Dense(15, activation='softmax'))

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Convert the target labels to one-hot encoding
y_train_onehot = tf.keras.utils.to_categorical(y_train)
y_test_onehot = tf.keras.utils.to_categorical(y_test)
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_6 (Conv3D)           (None, 20, 78, 110, 8)    656
#
#  batch_normalization_6 (Batc  (None, 20, 78, 110, 8)   32
#  hNormalization)
#
#  max_pooling3d_6 (MaxPooling  (None, 10, 39, 55, 8)    0
#  3D)
#
#  dropout_6 (Dropout)         (None, 10, 39, 55, 8)     0
#
#  conv3d_7 (Conv3D)           (None, 8, 37, 53, 8)      1736
#
#  batch_normalization_7 (Batc  (None, 8, 37, 53, 8)     32
#  hNormalization)
#
#  max_pooling3d_7 (MaxPooling  (None, 4, 18, 26, 8)     0
#  3D)
#
#  dropout_7 (Dropout)         (None, 4, 18, 26, 8)      0
#
#  reshape_3 (Reshape)         (None, 18, 832)           0
#
#  bidirectional_3 (Bidirectio  (None, 18, 128)          459264
#  nal)
#
#  flatten_3 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 15)                34575
#
# =================================================================
# Total params: 496,295
# Trainable params: 496,263
# Non-trainable params: 32
# _________________________________________________________________

# %% [markdown]
# # Training

# %%
# Train the model and record the history of training
history = model.fit(X_train, y_train_onehot, epochs=20, batch_size=8, validation_split=0.2, steps_per_epoch=35)
# Out:
# Epoch 1/20
# 35/35 [==============================] - 5s 70ms/step - loss: 7.4761 - accuracy: 0.0964 - val_loss: 6.2953 - val_accuracy: 0.1592
# Epoch 2/20
# 35/35 [==============================] - 2s 54ms/step - loss: 5.4429 - accuracy: 0.2321 - val_loss: 4.5940 - val_accuracy: 0.3183
# Epoch 3/20
# 35/35 [==============================] - 2s 54ms/step - loss: 4.0037 - accuracy: 0.4321 - val_loss: 3.2699 - val_accuracy: 0.5826
# Epoch 4/20
# 35/35 [==============================] - 2s 54ms/step - loss: 2.8222 - accuracy: 0.6357 - val_loss: 3.1030 - val_accuracy: 0.4775
# Epoch 5/20
# 35/35 [==============================] - 2s 54ms/step - loss: 2.0735 - accuracy: 0.7600 - val_loss: 2.6611 - val_accuracy: 0.4565
# Epoch 6/20
# 35/35 [==============================] - 2s 54ms/step - loss: 1.5792 - accuracy: 0.8714 - val_loss: 1.5653 - val_accuracy: 0.7868
# Epoch 7/20
# 35/35 [==============================] - 2s 54ms/step - loss: 1.2399 - accuracy: 0.8929 - val_loss: 1.8220 - val_accuracy: 0.6727
# Epoch 8/20
# 35/35 [==============================] - 2s 54ms/step - loss: 1.0466 - accuracy: 0.9250 - val_loss: 1.5851 - val_accuracy: 0.6787
# Epoch 9/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.9444 - accuracy: 0.9179 - val_loss: 1.4842 - val_accuracy: 0.7237
# Epoch 10/20
# 35/35 [==============================] - 2s 53ms/step - loss: 0.7303 - accuracy: 0.9709 - val_loss: 1.0241 - val_accuracy: 0.8378
# Epoch 11/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.7066 - accuracy: 0.9393 - val_loss: 1.2750 - val_accuracy: 0.7207
# Epoch 12/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.5577 - accuracy: 0.9750 - val_loss: 0.5546 - val_accuracy: 0.9640
# Epoch 13/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.5826 - accuracy: 0.9464 - val_loss: 0.7625 - val_accuracy: 0.8679
# Epoch 14/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.5288 - accuracy: 0.9393 - val_loss: 0.6921 - val_accuracy: 0.8829
# Epoch 15/20
# 35/35 [==============================] - 2s 53ms/step - loss: 0.4257 - accuracy: 0.9855 - val_loss: 0.5324 - val_accuracy: 0.9099
# Epoch 16/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.3757 - accuracy: 0.9893 - val_loss: 0.3948 - val_accuracy: 0.9580
# Epoch 17/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.3151 - accuracy: 0.9821 - val_loss: 0.6157 - val_accuracy: 0.8739
# Epoch 18/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.4188 - accuracy: 0.9500 - val_loss: 0.5454 - val_accuracy: 0.8979
# Epoch 19/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.3311 - accuracy: 0.9821 - val_loss: 0.3328 - val_accuracy: 0.9700
# Epoch 20/20
# 35/35 [==============================] - 2s 54ms/step - loss: 0.2925 - accuracy: 0.9818 - val_loss: 0.3439 - val_accuracy: 0.9700

# %% [markdown]
# # Performance Evaluation

# %%
# Plot the training and validation loss and accuracy
fig, axs = plt.subplots(2, 1, figsize=(8, 8))

axs[0].plot(history.history['loss'], label='Training Loss')
axs[0].plot(history.history['val_loss'], label='Validation Loss')
axs[0].legend(loc='upper right')
axs[0].set_ylabel('Loss')
axs[0].set_title('Training and Validation Loss')

axs[1].plot(history.history['accuracy'], label='Training Accuracy')
axs[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
axs[1].legend(loc='lower right')
axs[1].set_ylabel('Accuracy')
axs[1].set_title('Training and Validation Accuracy')

plt.xlabel('Epoch')
plt.show()

# %% [markdown]
# # Saving the Model

# %%
model.save_weights('model/model_weights_LSTM1.h5')

# %% [markdown]
# # Loading the Model

# %%
model.load_weights('model/model_weights_LSTM.h5', by_name=True)

# %% [markdown]
# # Validation

# %%
y_pred_prob = model.predict(X_test)
y_pred = np.argmax(y_pred_prob, axis=1)
# Out:
# 13/13 [==============================] - 1s 37ms/step

# %%
report = classification_report(y_test, y_pred, output_dict=True)

table = PrettyTable()
table.field_names = ["Class", "Precision", "Recall", "F1-Score", "Support"]
for label, metrics in report.items():
    if label.isdigit():
        precision = round(metrics['precision'], 2)
        recall = round(metrics['recall'], 2)
        f1_score = round(metrics['f1-score'], 2)
        support = metrics['support']
        table.add_row([label_dict[int(label)], precision, recall, f1_score, support])

print(table)
# Out:
# +-------+-----------+--------+----------+---------+
# | Class | Precision | Recall | F1-Score | Support |
# +-------+-----------+--------+----------+---------+
# |  अच्छा  |    1.0    |  0.9   |   0.95   |   30.0  |
# |   एक  |    0.94   |  0.89  |   0.92   |   38.0  |
# |   और  |    1.0    |  0.96  |   0.98   |   28.0  |
# |   कहाँ  |    0.8    |  0.97  |   0.88   |   36.0  |
# |   चार  |    0.81   |  0.96  |   0.88   |   23.0  |
# |   जी   |    1.0    |  1.0   |   1.0    |   22.0  |
# |   ठीक  |    1.0    |  0.94  |   0.97   |   31.0  |
# |   तीन  |    1.0    |  0.85  |   0.92   |   26.0  |
# |   दस  |    1.0    |  0.88  |   0.94   |   17.0  |
# |   देखो  |    0.97   |  1.0   |   0.98   |   31.0  |
# |  नमस्ते |    1.0    |  1.0   |   1.0    |   31.0  |
# |   पाँच  |    1.0    |  1.0   |   1.0    |   31.0  |
# |   पानी  |    1.0    |  0.86  |   0.92   |   21.0  |
# |   रोटी  |    0.85   |  1.0   |   0.92   |   23.0  |
# |   है   |    1.0    |  1.0   |   1.0    |   28.0  |
# +-------+-----------+--------+----------+---------+

# %%
print("Balanced accuracy:", balanced_accuracy_score(y_test, y_pred))
# Out:
# Balanced accuracy: 0.9472600022123034

# %% [markdown]
# # ROC

# %%
# Convert y_true and y_pred to one-hot encoding
n_classes = len(np.unique(y_test))
y_true_bin = label_binarize(y_test, classes=np.arange(n_classes))
y_pred_bin = model.predict(X_test)
y_pred_bin = label_binarize(np.argmax(y_pred_bin, axis=1), classes=np.arange(n_classes))

# Compute ROC curve and ROC AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true_bin[:, i], y_pred_bin[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC AUC
fpr_micro, tpr_micro, _ = roc_curve(y_true_bin.ravel(), y_pred_bin.ravel())
roc_auc_micro = auc(fpr_micro, tpr_micro)

# Plot ROC curves
plt.figure(figsize=(8,6))
lw = 2
colors = ['blue', 'red', 'green', 'orange', 'purple', 'black', 'brown', 'magenta', 'gray', 'maroon', 'navy', 'olive', 'pink']
for i, color in zip(range(n_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, 
             label='ROC curve of {0} (AUC = {1:0.2f})'.format(label_dict[i], roc_auc[i]))
plt.plot(fpr_micro, tpr_micro, color='darkorange', lw=lw,
         label='micro-average ROC curve (AUC = {0:0.2f})'
         ''.format(roc_auc_micro))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC AUC Curve')
plt.legend(loc="lower right", prop = fprop)
plt.show()
# Out:
# 13/13 [==============================] - 1s 59ms/step

# %% [markdown]
# # Confusion Matrix

# %%
conf_matrix = sklearn.metrics.confusion_matrix(y_test, y_pred)

# Define the list of label strings in the order of their integer values
label_strings = [label_dict[i] for i in range(len(label_dict))]

# Generate the heatmap confusion matrix
sns.heatmap(conf_matrix, annot=True, cmap="Blues", xticklabels=label_strings, yticklabels=label_strings)
plt.xticks(fontproperties=fprop)
plt.yticks(fontproperties=fprop)
plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix")
plt.show()
# Out:
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2309 (\N{DEVANAGARI LETTER A}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Matplotlib currently does not support Devanagari natively.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2330 (\N{DEVANAGARI LETTER CA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2381 (\N{DEVANAGARI SIGN VIRAMA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2331 (\N{DEVANAGARI LETTER CHA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2366 (\N{DEVANAGARI VOWEL SIGN AA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2319 (\N{DEVANAGARI LETTER E}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2325 (\N{DEVANAGARI LETTER KA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2324 (\N{DEVANAGARI LETTER AU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2352 (\N{DEVANAGARI LETTER RA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2361 (\N{DEVANAGARI LETTER HA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2305 (\N{DEVANAGARI SIGN CANDRABINDU}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2332 (\N{DEVANAGARI LETTER JA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2368 (\N{DEVANAGARI VOWEL SIGN II}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2336 (\N{DEVANAGARI LETTER TTHA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2340 (\N{DEVANAGARI LETTER TA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2344 (\N{DEVANAGARI LETTER NA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2342 (\N{DEVANAGARI LETTER DA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2360 (\N{DEVANAGARI LETTER SA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2375 (\N{DEVANAGARI VOWEL SIGN E}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2326 (\N{DEVANAGARI LETTER KHA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2379 (\N{DEVANAGARI VOWEL SIGN O}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2350 (\N{DEVANAGARI LETTER MA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2346 (\N{DEVANAGARI LETTER PA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2335 (\N{DEVANAGARI LETTER TTA}) missing from current font.
#   fig.canvas.draw()
# c:\Users\megar\AppData\Local\Programs\Python\Python38\lib\site-packages\seaborn\utils.py:61: UserWarning: Glyph 2376 (\N{DEVANAGARI VOWEL SIGN AI}) missing from current font.
#   fig.canvas.draw()
